# %% [markdown]
# # Election Analysis
# ## by Idongesit Inyang

# %% [markdown]
# # Investigation Overview
#
# The goal of the analysis is to explore and draw a predictive analysis for 2023 Prsidential election in Nigeria by regions.
#
# ### Dataset Overview
# I had access to four datasets consisting of candidates of 2015 and 2019 elections and the state and how each state voted.

# %%
#import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#read in the files
candi_2015 = pd.read_csv('ELECTION RESULT - 2015 BY CANDIDATE.csv')
state_2015 =pd.read_csv('ELECTION RESULT - 2015 BY STATE.csv')
candi_2019 = pd.read_csv('ELECTION RESULT - 2019 CANDIDATE.csv')
state_2019 = pd.read_csv('ELECTION RESULT - 2019 BY STATE.csv')

# %%
#load files
candi_2015_copy = candi_2015.copy()
candi_2015_copy
# Out:
#                                             Candidate  \
# 0                                    Muhammadu Buhari
# 1                                   Goodluck Jonathan
# 2                                       Adebayo Ayeni
# 3                                     Ganiyu Galadima
# 4                                             Sam Eke
# 5                                         Rufus Salau
# 6                                          Mani Ahmad
# 7                                     Allagoa Chinedu
# 8                                        Martin Onovo
# 9                              Tunde Anifowose-Kelani
# 10                                     Chekwas Okorie
# 11                                       Remi Sonaiya
# 12                                       Godson Okoye
# 13                               Ambrose Albert Owuru
# 14                                              Total
# 15                                                NaN
# 16                                        Valid votes
# 17                                Invalid/blank votes
# 18                                        Total votes
# 19                          Registered voters/turnout
# 20                                                NaN
# 21  Source: https://web.archive.org/web/2017032905...
#
#                                Party       Votes
# 0          All Progressives Congress  15,424,921
# 1          People's Democratic Party  12,853,162
# 2           African Peoples Alliance      53,537
# 3   Allied Congress Party of Nigeria      40,311
# 4             Citizens Popular Party      36,300
# 5             Alliance for Democracy      30,673
# 6        African Democratic Congress      29,666
# 7           Peoples Party of Nigeria      24,475
# 8          National Conscience Party      24,455
# 9                    Accord Alliance      22,125
# 10          United Progressive Party      18,220
# 11                        KOWA Party      13,076
# 12           United Democratic Party       9,208
# 13                        Hope Party       7,435
# 14                               NaN  28,587,564
# 15                               NaN         NaN
# 16                               NaN  28,587,564
# 17                               NaN     844,519
# 18                               NaN  29,432,083
# 19                               NaN  67,422,005
# 20                               NaN         NaN
# 21                               NaN         NaN

# %%
candi_2015_copy = candi_2015_copy.dropna()
candi_2015_copy
# Out:
#                  Candidate                             Party       Votes
# 0         Muhammadu Buhari         All Progressives Congress  15,424,921
# 1        Goodluck Jonathan         People's Democratic Party  12,853,162
# 2            Adebayo Ayeni          African Peoples Alliance      53,537
# 3          Ganiyu Galadima  Allied Congress Party of Nigeria      40,311
# 4                  Sam Eke            Citizens Popular Party      36,300
# 5              Rufus Salau            Alliance for Democracy      30,673
# 6               Mani Ahmad       African Democratic Congress      29,666
# 7          Allagoa Chinedu          Peoples Party of Nigeria      24,475
# 8             Martin Onovo         National Conscience Party      24,455
# 9   Tunde Anifowose-Kelani                   Accord Alliance      22,125
# 10          Chekwas Okorie          United Progressive Party      18,220
# 11            Remi Sonaiya                        KOWA Party      13,076
# 12            Godson Okoye           United Democratic Party       9,208
# 13    Ambrose Albert Owuru                        Hope Party       7,435

# %%
#remove the commas in the votes column and converting to integer
candi_2015_copy.Votes = candi_2015_copy.Votes.str.replace(',','')
candi_2015_copy.Votes = candi_2015_copy.Votes.astype(int)
candi_2015_copy
# Out:
#                  Candidate                             Party     Votes
# 0         Muhammadu Buhari         All Progressives Congress  15424921
# 1        Goodluck Jonathan         People's Democratic Party  12853162
# 2            Adebayo Ayeni          African Peoples Alliance     53537
# 3          Ganiyu Galadima  Allied Congress Party of Nigeria     40311
# 4                  Sam Eke            Citizens Popular Party     36300
# 5              Rufus Salau            Alliance for Democracy     30673
# 6               Mani Ahmad       African Democratic Congress     29666
# 7          Allagoa Chinedu          Peoples Party of Nigeria     24475
# 8             Martin Onovo         National Conscience Party     24455
# 9   Tunde Anifowose-Kelani                   Accord Alliance     22125
# 10          Chekwas Okorie          United Progressive Party     18220
# 11            Remi Sonaiya                        KOWA Party     13076
# 12            Godson Okoye           United Democratic Party      9208
# 13    Ambrose Albert Owuru                        Hope Party      7435

# %%
state_2015_copy = state_2015.copy()
state_2015_copy
# Out:
#                                                 State      Buhari    Jonathan  \
# 0                                               Total  15,424,921  12,853,162
# 1                                                Kano   1,903,999     215,779
# 2                                             Katsina   1,345,441      98,937
# 3                                              Kaduna   1,127,760     484,085
# 4                                              Bauchi     931,598      86,085
# 5                                              Jigawa     885,988     142,904
# 6                                               Lagos     792,460     632,327
# 7                                              Sokoto     671,926     152,199
# 8                                               Niger     657,678     149,222
# 9                                             Zamfara     612,202     144,833
# 10                                              Kebbi     567,883     100,972
# 11                                                Oyo     528,620     303,376
# 12                                              Borno     473,543      25,640
# 13                                               Yobe     446,265      25,526
# 14                                            Plateau     429,140     549,615
# 15                                               Osun     383,603     249,929
# 16                                            Adamawa     374,701     251,664
# 17                                              Benue     373,961     303,737
# 18                                              Gombe     361,245      96,873
# 19                                               Ogun     308,290     207,950
# 20                                              Kwara     302,146     132,602
# 21                                               Ondo     299,889     251,368
# 22                                               Kogi     264,851     149,987
# 23                                             Taraba     261,326     310,800
# 24                                          Nassarawa     236,838     273,460
# 25                                                Edo     208,469     286,869
# 26                                                FCT     146,399     157,195
# 27                                                Imo     133,253     559,185
# 28                                              Ekiti     120,331     176,466
# 29                                             Rivers      69,238   1,487,075
# 30                                          Akwa Ibom      58,411     953,304
# 31                                              Delta      48,910   1,211,405
# 32                                        Cross River      28,368     414,863
# 33                                             Ebonyi      19,518     323,653
# 34                                            Anambra      17,926     660,762
# 35                                              Enugu      14,157     553,003
# 36                                               Abia      13,394     368,303
# 37                                            Bayelsa       5,194     361,209
# 38  Source: https://web.archive.org/web/2017032905...         NaN         NaN
#
#      Ayeni Galadima     Eke   Salau   Ahmad Chinedu   Onovo  Kelani  Okorie  \
# 0   53,537   40,311  36,300  30,673  29,666  24,475  24,455  22,125  18,220
# 1    2,770      778   1,552     708     657     485     697     426     156
# 2    1,671      402     976     283     498     254     330     183      72
# 3    1,611      424     824     273     546     549     754     218      78
# 4      964      232     391     173     189     128     207     131      37
# 5    2,527      540   1,553     587     375     853     548     394     197
# 6    2,177    3,038   1,125   4,453   2,072   1,041   1,430   1,795     244
# 7    3,482      535   1,894     714     762     605     686     249     180
# 8    2,006      441   1,264     403     614     449     550     307     118
# 9    1,310      238     655     290     294     374     404     125      68
# 10   2,685      361   1,794     450     472     547     519     214     238
# 11   4,468    8,979   6,674   6,282   5,000   2,842   1,895   6,331   3,665
# 12     878      243     310     392     201     143     107     145      41
# 13     632      164     329     213     112     101     120     101      32
# 14     618      391     237     279     406     554     693     178      29
# 15   1,306    1,731   1,029   1,667     937     599     767     377     159
# 16   1,549    1,166     819     595   1,012   1,163   1,212     495     334
# 17     945    1,464     567     254     539     439     683     315      74
# 18     773      192     407     169     247     157     227     104      37
# 19   1,930    3,072     978   1,927   1,364   4,339     815     584     597
# 20   1,165      817     910     520     438     325     394     248     102
# 21   1,139    2,406   1,012   1,237   1,227     734     846     386     221
# 22   1,001    1,089     967     427     761     476     399     700     156
# 23   1,306      811   1,033     586     320     680     876     962     439
# 24     310       95     131      74     105     164     222      40      33
# 25     709    1,284     325     450     512     729     516     159      72
# 26     674      342     347     240     288     269     473     139      96
# 27   2,236      956     733     757   1,617     414     784     533   1,917
# 28     482      538     330     854     424     388     377      94     145
# 29     513      525     577   1,104   1,031     492     565   1,066     156
# 30     384      443     412     474     608     327     381   1,600     144
# 31     478      916     813     735     888     393     670   1,473     261
# 32     532      514     381     709     749     864     930     279   1,487
# 33   2,452    1,214   2,345   1,133   2,704   1,168   1,890     426   4,859
# 34   2,303    1,259   1,279     475     534     537     887     547   1,121
# 35     715      479     237     269     478     407     761     441     290
# 36   2,766    2,194   1,046     448     569     424     745     315     330
# 37      70       38      44      69     116      62      95      45      35
# 38     NaN      NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#    Sonaiya  Okoye  Owuru
# 0   13,076  9,208  7,435
# 1      288    234    292
# 2      215    117     47
# 3      176     79    105
# 4      128     29     46
# 5      423    338    337
# 6    1,000    269    255
# 7      475    269    283
# 8      305    116    198
# 9      122     93     14
# 10     448    207    213
# 11   1,312  1,069    839
# 12     158     31     88
# 13     104     30     67
# 14     138     54     56
# 15     255    124    132
# 16     752    289    267
# 17     105     66    115
# 18      97     25     46
# 19     432    562    332
# 20     214     81    118
# 21     223    184    184
# 22     190    180    144
# 23     153    224    161
# 24      48     23      4
# 25     175    160     22
# 26     165     95     83
# 27     158    264    157
# 28     108     60     94
# 29   2,274    303    542
# 30     160    224    192
# 31     311    354    166
# 32     312    289    237
# 33     913    624    989
# 34     311    286    357
# 35     203  1,623    110
# 36     173    213    125
# 37      52     20     18
# 38     NaN    NaN    NaN

# %%
state_2015_copy = state_2015_copy.dropna()

# %%
df_2015 = state_2015_copy.drop(state_2015_copy.index[0])
df_2015
# Out:
#           State     Buhari   Jonathan  Ayeni Galadima    Eke  Salau  Ahmad  \
# 1          Kano  1,903,999    215,779  2,770      778  1,552    708    657
# 2       Katsina  1,345,441     98,937  1,671      402    976    283    498
# 3        Kaduna  1,127,760    484,085  1,611      424    824    273    546
# 4        Bauchi    931,598     86,085    964      232    391    173    189
# 5        Jigawa    885,988    142,904  2,527      540  1,553    587    375
# 6         Lagos    792,460    632,327  2,177    3,038  1,125  4,453  2,072
# 7        Sokoto    671,926    152,199  3,482      535  1,894    714    762
# 8         Niger    657,678    149,222  2,006      441  1,264    403    614
# 9       Zamfara    612,202    144,833  1,310      238    655    290    294
# 10        Kebbi    567,883    100,972  2,685      361  1,794    450    472
# 11          Oyo    528,620    303,376  4,468    8,979  6,674  6,282  5,000
# 12        Borno    473,543     25,640    878      243    310    392    201
# 13         Yobe    446,265     25,526    632      164    329    213    112
# 14      Plateau    429,140    549,615    618      391    237    279    406
# 15         Osun    383,603    249,929  1,306    1,731  1,029  1,667    937
# 16      Adamawa    374,701    251,664  1,549    1,166    819    595  1,012
# 17        Benue    373,961    303,737    945    1,464    567    254    539
# 18        Gombe    361,245     96,873    773      192    407    169    247
# 19         Ogun    308,290    207,950  1,930    3,072    978  1,927  1,364
# 20        Kwara    302,146    132,602  1,165      817    910    520    438
# 21         Ondo    299,889    251,368  1,139    2,406  1,012  1,237  1,227
# 22         Kogi    264,851    149,987  1,001    1,089    967    427    761
# 23       Taraba    261,326    310,800  1,306      811  1,033    586    320
# 24    Nassarawa    236,838    273,460    310       95    131     74    105
# 25          Edo    208,469    286,869    709    1,284    325    450    512
# 26          FCT    146,399    157,195    674      342    347    240    288
# 27          Imo    133,253    559,185  2,236      956    733    757  1,617
# 28        Ekiti    120,331    176,466    482      538    330    854    424
# 29       Rivers     69,238  1,487,075    513      525    577  1,104  1,031
# 30    Akwa Ibom     58,411    953,304    384      443    412    474    608
# 31        Delta     48,910  1,211,405    478      916    813    735    888
# 32  Cross River     28,368    414,863    532      514    381    709    749
# 33       Ebonyi     19,518    323,653  2,452    1,214  2,345  1,133  2,704
# 34      Anambra     17,926    660,762  2,303    1,259  1,279    475    534
# 35        Enugu     14,157    553,003    715      479    237    269    478
# 36         Abia     13,394    368,303  2,766    2,194  1,046    448    569
# 37      Bayelsa      5,194    361,209     70       38     44     69    116
#
#    Chinedu  Onovo Kelani Okorie Sonaiya  Okoye Owuru
# 1      485    697    426    156     288    234   292
# 2      254    330    183     72     215    117    47
# 3      549    754    218     78     176     79   105
# 4      128    207    131     37     128     29    46
# 5      853    548    394    197     423    338   337
# 6    1,041  1,430  1,795    244   1,000    269   255
# 7      605    686    249    180     475    269   283
# 8      449    550    307    118     305    116   198
# 9      374    404    125     68     122     93    14
# 10     547    519    214    238     448    207   213
# 11   2,842  1,895  6,331  3,665   1,312  1,069   839
# 12     143    107    145     41     158     31    88
# 13     101    120    101     32     104     30    67
# 14     554    693    178     29     138     54    56
# 15     599    767    377    159     255    124   132
# 16   1,163  1,212    495    334     752    289   267
# 17     439    683    315     74     105     66   115
# 18     157    227    104     37      97     25    46
# 19   4,339    815    584    597     432    562   332
# 20     325    394    248    102     214     81   118
# 21     734    846    386    221     223    184   184
# 22     476    399    700    156     190    180   144
# 23     680    876    962    439     153    224   161
# 24     164    222     40     33      48     23     4
# 25     729    516    159     72     175    160    22
# 26     269    473    139     96     165     95    83
# 27     414    784    533  1,917     158    264   157
# 28     388    377     94    145     108     60    94
# 29     492    565  1,066    156   2,274    303   542
# 30     327    381  1,600    144     160    224   192
# 31     393    670  1,473    261     311    354   166
# 32     864    930    279  1,487     312    289   237
# 33   1,168  1,890    426  4,859     913    624   989
# 34     537    887    547  1,121     311    286   357
# 35     407    761    441    290     203  1,623   110
# 36     424    745    315    330     173    213   125
# 37      62     95     45     35      52     20    18

# %%
cols = ['Buhari', 'Jonathan', 'Ayeni', 'Galadima', 'Eke', 'Salau',
       'Ahmad', 'Chinedu', 'Onovo', 'Kelani', 'Okorie', 'Sonaiya', 'Okoye',
       'Owuru']

# %%
#clean the data
for c in cols:
    df_2015[c] = df_2015[c].str.replace(',','')
    df_2015[c] = df_2015[c].astype(int)
df_2015
# Out:
#           State   Buhari  Jonathan  Ayeni  Galadima   Eke  Salau  Ahmad  \
# 1          Kano  1903999    215779   2770       778  1552    708    657
# 2       Katsina  1345441     98937   1671       402   976    283    498
# 3        Kaduna  1127760    484085   1611       424   824    273    546
# 4        Bauchi   931598     86085    964       232   391    173    189
# 5        Jigawa   885988    142904   2527       540  1553    587    375
# 6         Lagos   792460    632327   2177      3038  1125   4453   2072
# 7        Sokoto   671926    152199   3482       535  1894    714    762
# 8         Niger   657678    149222   2006       441  1264    403    614
# 9       Zamfara   612202    144833   1310       238   655    290    294
# 10        Kebbi   567883    100972   2685       361  1794    450    472
# 11          Oyo   528620    303376   4468      8979  6674   6282   5000
# 12        Borno   473543     25640    878       243   310    392    201
# 13         Yobe   446265     25526    632       164   329    213    112
# 14      Plateau   429140    549615    618       391   237    279    406
# 15         Osun   383603    249929   1306      1731  1029   1667    937
# 16      Adamawa   374701    251664   1549      1166   819    595   1012
# 17        Benue   373961    303737    945      1464   567    254    539
# 18        Gombe   361245     96873    773       192   407    169    247
# 19         Ogun   308290    207950   1930      3072   978   1927   1364
# 20        Kwara   302146    132602   1165       817   910    520    438
# 21         Ondo   299889    251368   1139      2406  1012   1237   1227
# 22         Kogi   264851    149987   1001      1089   967    427    761
# 23       Taraba   261326    310800   1306       811  1033    586    320
# 24    Nassarawa   236838    273460    310        95   131     74    105
# 25          Edo   208469    286869    709      1284   325    450    512
# 26          FCT   146399    157195    674       342   347    240    288
# 27          Imo   133253    559185   2236       956   733    757   1617
# 28        Ekiti   120331    176466    482       538   330    854    424
# 29       Rivers    69238   1487075    513       525   577   1104   1031
# 30    Akwa Ibom    58411    953304    384       443   412    474    608
# 31        Delta    48910   1211405    478       916   813    735    888
# 32  Cross River    28368    414863    532       514   381    709    749
# 33       Ebonyi    19518    323653   2452      1214  2345   1133   2704
# 34      Anambra    17926    660762   2303      1259  1279    475    534
# 35        Enugu    14157    553003    715       479   237    269    478
# 36         Abia    13394    368303   2766      2194  1046    448    569
# 37      Bayelsa     5194    361209     70        38    44     69    116
#
#     Chinedu  Onovo  Kelani  Okorie  Sonaiya  Okoye  Owuru
# 1       485    697     426     156      288    234    292
# 2       254    330     183      72      215    117     47
# 3       549    754     218      78      176     79    105
# 4       128    207     131      37      128     29     46
# 5       853    548     394     197      423    338    337
# 6      1041   1430    1795     244     1000    269    255
# 7       605    686     249     180      475    269    283
# 8       449    550     307     118      305    116    198
# 9       374    404     125      68      122     93     14
# 10      547    519     214     238      448    207    213
# 11     2842   1895    6331    3665     1312   1069    839
# 12      143    107     145      41      158     31     88
# 13      101    120     101      32      104     30     67
# 14      554    693     178      29      138     54     56
# 15      599    767     377     159      255    124    132
# 16     1163   1212     495     334      752    289    267
# 17      439    683     315      74      105     66    115
# 18      157    227     104      37       97     25     46
# 19     4339    815     584     597      432    562    332
# 20      325    394     248     102      214     81    118
# 21      734    846     386     221      223    184    184
# 22      476    399     700     156      190    180    144
# 23      680    876     962     439      153    224    161
# 24      164    222      40      33       48     23      4
# 25      729    516     159      72      175    160     22
# 26      269    473     139      96      165     95     83
# 27      414    784     533    1917      158    264    157
# 28      388    377      94     145      108     60     94
# 29      492    565    1066     156     2274    303    542
# 30      327    381    1600     144      160    224    192
# 31      393    670    1473     261      311    354    166
# 32      864    930     279    1487      312    289    237
# 33     1168   1890     426    4859      913    624    989
# 34      537    887     547    1121      311    286    357
# 35      407    761     441     290      203   1623    110
# 36      424    745     315     330      173    213    125
# 37       62     95      45      35       52     20     18

# %%
df_2015['Region'] = np.nan

# %%
# create the various regions
North_Central = ['Benue', 'Kogi', 'Kwara', 'Nassarawa', 'Niger', 'Plateau', 'FCT']
North_East = ['Adamawa', 'Bauchi', 'Borno', 'Gombe', 'Taraba', 'Yobe', np.nan ]
North_West = ['Jigawa', 'Kaduna', 'Kano', 'Katsina', 'Kebbi', 'Sokoto', 'Zamfara']
South_East = ['Abia', 'Anambra', 'Ebonyi', 'Enugu', 'Imo', np.nan,np.nan]
South_South = ['Akwa Ibom', 'Bayelsa', 'Cross River', 'Delta', 'Edo', 'Rivers', np.nan]
South_West = ['Ekiti', 'Lagos', 'Ogun', 'Ondo', 'Osun', 'Oyo',np.nan]

# %%
def fill_region(region, r=''):
    '''Function that checks and assigns regions into the Region column'''
    df_2015.loc[df_2015.State.isin(region), 'Region'] = r

# %%
fill_region(North_Central, 'North_Central')
fill_region(North_East, 'North_East')
fill_region(North_West,'North_West')
fill_region(South_East, 'South_East')
fill_region(South_South, 'South_South')
fill_region(South_West, 'South_West')

# %%
df_2015
# Out:
#           State   Buhari  Jonathan  Ayeni  Galadima   Eke  Salau  Ahmad  \
# 1          Kano  1903999    215779   2770       778  1552    708    657
# 2       Katsina  1345441     98937   1671       402   976    283    498
# 3        Kaduna  1127760    484085   1611       424   824    273    546
# 4        Bauchi   931598     86085    964       232   391    173    189
# 5        Jigawa   885988    142904   2527       540  1553    587    375
# 6         Lagos   792460    632327   2177      3038  1125   4453   2072
# 7        Sokoto   671926    152199   3482       535  1894    714    762
# 8         Niger   657678    149222   2006       441  1264    403    614
# 9       Zamfara   612202    144833   1310       238   655    290    294
# 10        Kebbi   567883    100972   2685       361  1794    450    472
# 11          Oyo   528620    303376   4468      8979  6674   6282   5000
# 12        Borno   473543     25640    878       243   310    392    201
# 13         Yobe   446265     25526    632       164   329    213    112
# 14      Plateau   429140    549615    618       391   237    279    406
# 15         Osun   383603    249929   1306      1731  1029   1667    937
# 16      Adamawa   374701    251664   1549      1166   819    595   1012
# 17        Benue   373961    303737    945      1464   567    254    539
# 18        Gombe   361245     96873    773       192   407    169    247
# 19         Ogun   308290    207950   1930      3072   978   1927   1364
# 20        Kwara   302146    132602   1165       817   910    520    438
# 21         Ondo   299889    251368   1139      2406  1012   1237   1227
# 22         Kogi   264851    149987   1001      1089   967    427    761
# 23       Taraba   261326    310800   1306       811  1033    586    320
# 24    Nassarawa   236838    273460    310        95   131     74    105
# 25          Edo   208469    286869    709      1284   325    450    512
# 26          FCT   146399    157195    674       342   347    240    288
# 27          Imo   133253    559185   2236       956   733    757   1617
# 28        Ekiti   120331    176466    482       538   330    854    424
# 29       Rivers    69238   1487075    513       525   577   1104   1031
# 30    Akwa Ibom    58411    953304    384       443   412    474    608
# 31        Delta    48910   1211405    478       916   813    735    888
# 32  Cross River    28368    414863    532       514   381    709    749
# 33       Ebonyi    19518    323653   2452      1214  2345   1133   2704
# 34      Anambra    17926    660762   2303      1259  1279    475    534
# 35        Enugu    14157    553003    715       479   237    269    478
# 36         Abia    13394    368303   2766      2194  1046    448    569
# 37      Bayelsa     5194    361209     70        38    44     69    116
#
#     Chinedu  Onovo  Kelani  Okorie  Sonaiya  Okoye  Owuru         Region
# 1       485    697     426     156      288    234    292     North_West
# 2       254    330     183      72      215    117     47     North_West
# 3       549    754     218      78      176     79    105     North_West
# 4       128    207     131      37      128     29     46     North_East
# 5       853    548     394     197      423    338    337     North_West
# 6      1041   1430    1795     244     1000    269    255     South_West
# 7       605    686     249     180      475    269    283     North_West
# 8       449    550     307     118      305    116    198  North_Central
# 9       374    404     125      68      122     93     14     North_West
# 10      547    519     214     238      448    207    213     North_West
# 11     2842   1895    6331    3665     1312   1069    839     South_West
# 12      143    107     145      41      158     31     88     North_East
# 13      101    120     101      32      104     30     67     North_East
# 14      554    693     178      29      138     54     56  North_Central
# 15      599    767     377     159      255    124    132     South_West
# 16     1163   1212     495     334      752    289    267     North_East
# 17      439    683     315      74      105     66    115  North_Central
# 18      157    227     104      37       97     25     46     North_East
# 19     4339    815     584     597      432    562    332     South_West
# 20      325    394     248     102      214     81    118  North_Central
# 21      734    846     386     221      223    184    184     South_West
# 22      476    399     700     156      190    180    144  North_Central
# 23      680    876     962     439      153    224    161     North_East
# 24      164    222      40      33       48     23      4  North_Central
# 25      729    516     159      72      175    160     22    South_South
# 26      269    473     139      96      165     95     83  North_Central
# 27      414    784     533    1917      158    264    157     South_East
# 28      388    377      94     145      108     60     94     South_West
# 29      492    565    1066     156     2274    303    542    South_South
# 30      327    381    1600     144      160    224    192    South_South
# 31      393    670    1473     261      311    354    166    South_South
# 32      864    930     279    1487      312    289    237    South_South
# 33     1168   1890     426    4859      913    624    989     South_East
# 34      537    887     547    1121      311    286    357     South_East
# 35      407    761     441     290      203   1623    110     South_East
# 36      424    745     315     330      173    213    125     South_East
# 37       62     95      45      35       52     20     18    South_South

# %%
candi_2019_copy = candi_2019.copy()
candi_2019_copy
#candi_2019
# Out:
#             NAME OF CANDIDATE GENDER PARTY VOTES RECEIVED  REMARKS
# 0            BUHARI MUHAMMADU      M   APC     15,191,847  ELECTED
# 1              ABUBAKAR ATIKU      M   PDP     11,262,978      NaN
# 2               FELIX NICOLAS      M   PCP        110,196      NaN
# 3            MAILAFIA OBADIAH      M   ADC         97,874      NaN
# 4    GBOR JOHN WILSON TERWASE      M  APGA         66,851      NaN
# ..                        ...    ...   ...            ...      ...
# 68  ADEMOLA BABATUNDE ABIDEMI      M  NCMP          1,378      NaN
# 69       A. EDOSOMWAN JOHNSON      M  NDCP          1,192      NaN
# 70         ABAH LEWIS ELAIGWU      M   CAP          1,111      NaN
# 71             ANGELA JOHNSON      F   AUN          1,092      NaN
# 72      NWANGWU UCHENNA PETER      M  WTPN            732      NaN
#
# [73 rows x 5 columns]

# %%
candi_2019_copy['REMARKS'] = np.where(candi_2019_copy['REMARKS'] =="ELECTED",1,0)

# %%
candi_2019_copy['VOTES RECEIVED'] = candi_2019_copy['VOTES RECEIVED'].str.replace(',','')
candi_2019_copy['VOTES RECEIVED'] = candi_2019_copy['VOTES RECEIVED'].astype(int)
candi_2019_copy
# Out:
#             NAME OF CANDIDATE GENDER PARTY  VOTES RECEIVED  REMARKS
# 0            BUHARI MUHAMMADU      M   APC        15191847        1
# 1              ABUBAKAR ATIKU      M   PDP        11262978        0
# 2               FELIX NICOLAS      M   PCP          110196        0
# 3            MAILAFIA OBADIAH      M   ADC           97874        0
# 4    GBOR JOHN WILSON TERWASE      M  APGA           66851        0
# ..                        ...    ...   ...             ...      ...
# 68  ADEMOLA BABATUNDE ABIDEMI      M  NCMP            1378        0
# 69       A. EDOSOMWAN JOHNSON      M  NDCP            1192        0
# 70         ABAH LEWIS ELAIGWU      M   CAP            1111        0
# 71             ANGELA JOHNSON      F   AUN            1092        0
# 72      NWANGWU UCHENNA PETER      M  WTPN             732        0
#
# [73 rows x 5 columns]

# %%
df_2019 = pd.read_csv('df_2019 - ELECTION RESULT - 2019 BY STATE.csv')
df_2019
# Out:
#           State      Buhari       Atiku  Nicolas  Sowore Moghalu Durotoye  \
# 0          Abia      85,058     219,698    1,489     212      88      720
# 1       Adamawa     378,078     410,266    3,670     282     109      162
# 2     Akwa Ibom     175,429     395,832    1,902     222     118       95
# 3       Anambra      33,298     524,738    4,374     124   4,091       45
# 4        Bauchi     798,428     209,313    2,104     183     112       46
# 5       Bayelsa     118,821     197,933    1,584     126      50       37
# 6         Benue     347,668     356,817    2,793     309     557      201
# 7         Borno     836,496      71,788        0     269      78       29
# 8   Cross River     117,302     295,737        0     242     217       88
# 9         Delta     221,292     594,068        0   1,626     497      320
# 10       Ebonyi      90,726     258,573        0     205     192      683
# 11          Edo     267,842     275,691        0   3,106     531      273
# 12        Ekiti     219,231     154,032        0     400      68       88
# 13        Enugu      54,423     355,553        0     219   1,379      141
# 14          FCT     152,224     259,997        0     583   1,083      652
# 15        Gombe     402,961     138,484        0     165      39       78
# 16          Imo     140,463     334,923        0     467     676      119
# 17       Jigawa     794,738     289,895        0     226      67       66
# 18       Kaduna     993,445     649,612        0     243     196      261
# 19         Kano   1,464,768     391,593        0     416     200      114
# 20      Katsina   1,232,133     308,056        0     186      61       82
# 21        Kebbi     581,552     154,282        0     276      53       99
# 22         Kogi     285,894     218,207        0     250      87       89
# 23        Kwara     308,984     138,184        0     401     140      422
# 24        Lagos     580,825     448,015        0   8,910   5,733    6,946
# 25    Nassarawa     289,903     283,847        0      75      44       45
# 26        Niger     612,371     218,052        0     324     113      145
# 27         Ogun     281,762     194,655        0   3,196     553    1,509
# 28         Ondo     241,769     275,901        0   4,414    1224      311
# 29         Osun     347,634     337,377        0   1,022     189      268
# 30          Oyo     365,229     366,690        0   4,014   1,608    1,896
# 31      Plateau     468,555     548,665        0     268     442      796
# 32       Rivers     150,710     473,971        0     372     415      365
# 33       Sokoto     490,333     361,604        0     181     184       84
# 34       Taraba     324,906     374,743        0     116      80       35
# 35        Total  15,191,847  11,262,978  110,196  33,953  21,886   16,779
# 36         Yobe     497,914      50,763        0     137      36       37
# 37      Zamfara     438,682     125,423        0     186      44       24
#
#       Duke Mailafia
# 0      472      336
# 1      978    3,989
# 2       92      230
# 3      932      227
# 4      516      296
# 5      124    1,078
# 6    4,927      554
# 7      322      301
# 8    1,395      326
# 9    1,745    1,075
# 10     452      213
# 11     184      850
# 12      48      406
# 13     130      348
# 14     410      246
# 15     248      248
# 16     772      541
# 17   5,011      261
# 18   1,737      558
# 19     635      591
# 20     150      237
# 21   2,376      285
# 22   2,226    4,369
# 23     212      456
# 24     770    2,915
# 25     359      339
# 26     239      588
# 27   1,374   25,283
# 28   1,618    6,296
# 29     259    1,525
# 30     766   40,830
# 31     599      590
# 32   1,244      597
# 33     301      331
# 34     862      211
# 35  34,746   97,874
# 36     180      162
# 37      81      186

# %%
df_2019 = df_2019.drop(df_2019.index[[35]])
df_2019.reset_index(inplace=True)

# %%
df_2019.drop('index', axis=1,inplace=True)
df_2019
# Out:
#           State     Buhari    Atiku Nicolas Sowore Moghalu Durotoye   Duke  \
# 0          Abia     85,058  219,698   1,489    212      88      720    472
# 1       Adamawa    378,078  410,266   3,670    282     109      162    978
# 2     Akwa Ibom    175,429  395,832   1,902    222     118       95     92
# 3       Anambra     33,298  524,738   4,374    124   4,091       45    932
# 4        Bauchi    798,428  209,313   2,104    183     112       46    516
# 5       Bayelsa    118,821  197,933   1,584    126      50       37    124
# 6         Benue    347,668  356,817   2,793    309     557      201  4,927
# 7         Borno    836,496   71,788       0    269      78       29    322
# 8   Cross River    117,302  295,737       0    242     217       88  1,395
# 9         Delta    221,292  594,068       0  1,626     497      320  1,745
# 10       Ebonyi     90,726  258,573       0    205     192      683    452
# 11          Edo    267,842  275,691       0  3,106     531      273    184
# 12        Ekiti    219,231  154,032       0    400      68       88     48
# 13        Enugu     54,423  355,553       0    219   1,379      141    130
# 14          FCT    152,224  259,997       0    583   1,083      652    410
# 15        Gombe    402,961  138,484       0    165      39       78    248
# 16          Imo    140,463  334,923       0    467     676      119    772
# 17       Jigawa    794,738  289,895       0    226      67       66  5,011
# 18       Kaduna    993,445  649,612       0    243     196      261  1,737
# 19         Kano  1,464,768  391,593       0    416     200      114    635
# 20      Katsina  1,232,133  308,056       0    186      61       82    150
# 21        Kebbi    581,552  154,282       0    276      53       99  2,376
# 22         Kogi    285,894  218,207       0    250      87       89  2,226
# 23        Kwara    308,984  138,184       0    401     140      422    212
# 24        Lagos    580,825  448,015       0  8,910   5,733    6,946    770
# 25    Nassarawa    289,903  283,847       0     75      44       45    359
# 26        Niger    612,371  218,052       0    324     113      145    239
# 27         Ogun    281,762  194,655       0  3,196     553    1,509  1,374
# 28         Ondo    241,769  275,901       0  4,414    1224      311  1,618
# 29         Osun    347,634  337,377       0  1,022     189      268    259
# 30          Oyo    365,229  366,690       0  4,014   1,608    1,896    766
# 31      Plateau    468,555  548,665       0    268     442      796    599
# 32       Rivers    150,710  473,971       0    372     415      365  1,244
# 33       Sokoto    490,333  361,604       0    181     184       84    301
# 34       Taraba    324,906  374,743       0    116      80       35    862
# 35         Yobe    497,914   50,763       0    137      36       37    180
# 36      Zamfara    438,682  125,423       0    186      44       24     81
#
#    Mailafia
# 0       336
# 1     3,989
# 2       230
# 3       227
# 4       296
# 5     1,078
# 6       554
# 7       301
# 8       326
# 9     1,075
# 10      213
# 11      850
# 12      406
# 13      348
# 14      246
# 15      248
# 16      541
# 17      261
# 18      558
# 19      591
# 20      237
# 21      285
# 22    4,369
# 23      456
# 24    2,915
# 25      339
# 26      588
# 27   25,283
# 28    6,296
# 29    1,525
# 30   40,830
# 31      590
# 32      597
# 33      331
# 34      211
# 35      162
# 36      186

# %%
colss = ['Buhari','Atiku','Nicolas', 'Sowore', 'Moghalu',
       'Durotoye', 'Duke', 'Mailafia']

# %%
for c in colss:
    
    df_2019[c] = df_2019[c].str.replace(',','')
    df_2019[c] = df_2019[c].astype(int)

# %%
def fill_region(df, region, r=''):
    df.loc[df.State.isin(region), 'Region'] = r

# %%
fill_region(df_2019, North_Central, 'North_Central')
fill_region(df_2019, South_South, 'South_South')
fill_region(df_2019, South_East, 'South_East')
fill_region(df_2019, South_West, 'South_West')
fill_region(df_2019,North_East, 'North_East')
fill_region(df_2019, North_West,'North_West')

# %%
df_2019
# Out:
#           State   Buhari   Atiku  Nicolas  Sowore  Moghalu  Durotoye  Duke  \
# 0          Abia    85058  219698     1489     212       88       720   472
# 1       Adamawa   378078  410266     3670     282      109       162   978
# 2     Akwa Ibom   175429  395832     1902     222      118        95    92
# 3       Anambra    33298  524738     4374     124     4091        45   932
# 4        Bauchi   798428  209313     2104     183      112        46   516
# 5       Bayelsa   118821  197933     1584     126       50        37   124
# 6         Benue   347668  356817     2793     309      557       201  4927
# 7         Borno   836496   71788        0     269       78        29   322
# 8   Cross River   117302  295737        0     242      217        88  1395
# 9         Delta   221292  594068        0    1626      497       320  1745
# 10       Ebonyi    90726  258573        0     205      192       683   452
# 11          Edo   267842  275691        0    3106      531       273   184
# 12        Ekiti   219231  154032        0     400       68        88    48
# 13        Enugu    54423  355553        0     219     1379       141   130
# 14          FCT   152224  259997        0     583     1083       652   410
# 15        Gombe   402961  138484        0     165       39        78   248
# 16          Imo   140463  334923        0     467      676       119   772
# 17       Jigawa   794738  289895        0     226       67        66  5011
# 18       Kaduna   993445  649612        0     243      196       261  1737
# 19         Kano  1464768  391593        0     416      200       114   635
# 20      Katsina  1232133  308056        0     186       61        82   150
# 21        Kebbi   581552  154282        0     276       53        99  2376
# 22         Kogi   285894  218207        0     250       87        89  2226
# 23        Kwara   308984  138184        0     401      140       422   212
# 24        Lagos   580825  448015        0    8910     5733      6946   770
# 25    Nassarawa   289903  283847        0      75       44        45   359
# 26        Niger   612371  218052        0     324      113       145   239
# 27         Ogun   281762  194655        0    3196      553      1509  1374
# 28         Ondo   241769  275901        0    4414     1224       311  1618
# 29         Osun   347634  337377        0    1022      189       268   259
# 30          Oyo   365229  366690        0    4014     1608      1896   766
# 31      Plateau   468555  548665        0     268      442       796   599
# 32       Rivers   150710  473971        0     372      415       365  1244
# 33       Sokoto   490333  361604        0     181      184        84   301
# 34       Taraba   324906  374743        0     116       80        35   862
# 35         Yobe   497914   50763        0     137       36        37   180
# 36      Zamfara   438682  125423        0     186       44        24    81
#
#     Mailafia         Region
# 0        336     South_East
# 1       3989     North_East
# 2        230    South_South
# 3        227     South_East
# 4        296     North_East
# 5       1078    South_South
# 6        554  North_Central
# 7        301     North_East
# 8        326    South_South
# 9       1075    South_South
# 10       213     South_East
# 11       850    South_South
# 12       406     South_West
# 13       348     South_East
# 14       246  North_Central
# 15       248     North_East
# 16       541     South_East
# 17       261     North_West
# 18       558     North_West
# 19       591     North_West
# 20       237     North_West
# 21       285     North_West
# 22      4369  North_Central
# 23       456  North_Central
# 24      2915     South_West
# 25       339  North_Central
# 26       588  North_Central
# 27     25283     South_West
# 28      6296     South_West
# 29      1525     South_West
# 30     40830     South_West
# 31       590  North_Central
# 32       597    South_South
# 33       331     North_West
# 34       211     North_East
# 35       162     North_East
# 36       186     North_West

# %% [markdown]
# #  What is the percentage of Male to women in the 2019 election?

# %%
gender = candi_2019_copy['GENDER'].value_counts()
gen_order = gender.index
no_candi  = candi_2019_copy['GENDER'].value_counts().sum()
max_gen = gender[0]
max_prop = max_gen / no_candi

#considering the same chart above, print the text (proportion) on the bars
plt.figure(figsize=(12,5))
base_color = sns.color_palette()[0]
sns.countplot(data=candi_2019_copy, y='GENDER',color=base_color, order=gen_order);
#plt.rcParams['figure.figsize'] = 12,4
#logic to print the proportion text on the bars
for i in range(gender.shape[0]):
    
    #remember type_counts contains the frequency of unique values in the 'type' column in decreasing order.
    count = gender[i]
    #convert count into a percentage, and then into string
    pct_string = '{:0.1f}%'.format(100*count/no_candi)
    #print the string value on the bar.
    plt.title('Proportion of male to female in 2019 Election', fontsize = 20)
    plt.text(count+1, i, pct_string, va='center')

# %% [markdown]
# There are 67 males(92%) and 6 female(8%)

# %% [markdown]
# # How many votes did each candidate have in 2015?

# %%
candi_2015 = df_2015[['Buhari', 'Jonathan', 'Ayeni', 'Galadima', 'Eke', 'Salau',
       'Ahmad', 'Chinedu', 'Onovo', 'Kelani', 'Okorie', 'Sonaiya', 'Okoye',
       'Owuru']]

candi_sum = candi_2015.sum()

candi_sum.plot(kind='bar', figsize=(20, 5), color='blue')
plt.title('Plot showing the votes each candidate had in 2015', fontsize = 20)
plt.xlabel('Candidates')
plt.ylabel('No of Votes')
plt.show()

# %% [markdown]
# The visualization shows that it was a two candidate race in 2015 as Buhari and Jonathan had the highest votes.

# %% [markdown]
# # How many votes did each candidate have in 2019?

# %%
candi_2019 = df_2019[['Buhari','Atiku','Nicolas', 'Sowore', 'Moghalu',
       'Durotoye', 'Duke', 'Mailafia']]

candi_sum = candi_2019.sum()

candi_sum.plot(kind='bar', figsize=(20, 5), color='blue')
plt.xlabel('Candidates', fontsize=10)
plt.ylabel('No of votes')
plt.title('Plot showing the votes each candidate had in 2019', fontsize = 20)
plt.show()

# %% [markdown]
# Similarly, it was a two candidate race in 2019 as Buhari and Atiku had the highest votes.

# %% [markdown]
# # Which region did the top two candidates have the most votes in the 2015?

# %%
df_2015.groupby('Region').sum()

by_region_2015_buhari = df_2015.groupby('Region')['Buhari'].sum()
by_region_2015_buhari.sort_values(ascending=False)

plt.figure(figsize=(12,5))
color = sns.color_palette()[0]
sns.barplot(data = df_2015, x='Region',y='Buhari', color = color)
plt.xticks(rotation=0)
plt.title('Plot showing how Buhari was voted by Region in 2015', fontsize=20)
plt.show()

# %% [markdown]
# Buhari got his highest number of votes from the North West region(7,115,199), followed by North East(2,848,678), South West (2,433,193)and North Central(2,411,013).

# %% [markdown]
# #### Jonathan

# %%
by_region_2015_jona = df_2015.groupby('Region')['Jonathan'].sum()
by_region_2015_jona.sort_values(ascending=False)

plt.figure(figsize=(12,5))
color = sns.color_palette()[0]
sns.barplot(data = df_2015, x='Region',y='Jonathan', color = color)
plt.xticks(rotation=0)
plt.title('Plot showing how Jonathan was voted by Region in 2015', fontsize=20)
plt.show()

# %% [markdown]
# Jonathan got his highest votes from the South South region(4,714,725), followed by South East(2,464,906), and South West(1,821,416)

# %% [markdown]
# # Which region did the top two candidates have the most votes in the 2019

# %%
df_2019.groupby('Region').sum()

plt.figure(figsize=(12,5))
color = sns.color_palette()[0]
sns.barplot(data = df_2019, x='Region',y='Buhari', color = color)
plt.xticks(rotation=0)
plt.title('Plot showing how Buhari was voted by Region in 2019', fontsize=20)
plt.show()

# %% [markdown]
# In 2019 election, Buhari of APC had the highest votes from North West, North East, North Central and South West.

# %%
plt.figure(figsize=(12,5))
color = sns.color_palette()[0]
sns.barplot(data = df_2019, x='Region',y='Atiku', color = color)
plt.xticks(rotation=0)
plt.title('Plot showing how Atiku was voted by Region in 2019', fontsize=20)
plt.show()

# %% [markdown]
# In 2019 election, Atiku of PDP had the highest votes from South South followed by South East, North West.

# %%
by_region = df_2015.groupby('Region').sum()
by_region.plot( y=['Buhari', 'Jonathan'], kind = 'bar', figsize=(20, 5), grid=1)
plt.title('Plot showing how the Top two candidate were voted by region in 2015', fontsize=20)
plt.show()

# %%
by_region = df_2019.groupby('Region').sum()
by_region.plot( y=['Buhari', 'Atiku'], kind = 'bar', figsize=(20, 5), grid=1)
plt.title('Plot showing how the Top two candidate were voted by region in 2019', fontsize=20)
plt.show()

# %% [markdown]
# # Conclusion
#
# 1) Buhari(APC) had more votes in the Northern region of Nigeria and in the south westin both 2015 and 2019 election
#
# 2) Atiku (PDP) had more votes in South south and South East
#
# 3) This shows how strong APC party have held down the Northen and South Western region of Nigeria.

# %%
# !jupyter nbconvert Election_Analysis_Slides.ipynb --to slides --post serve --no-input --no-prompt
# Out:
# ^C
